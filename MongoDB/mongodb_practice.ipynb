# %% [markdown]
# ### Importing libs and connecting to the database

# %%
import pymongo
import json
import math
import datetime
from pymongo import MongoClient, InsertOne
from pprint import pprint # for pretty print
from pymongo import ASCENDING, DESCENDING
from pymongo import GEO2D
from pymongo import GEOSPHERE 

CONNECTION_STRING = "mongodb://localhost:27017/"
DATABASE = "citytransportweb"

client = pymongo.MongoClient(CONNECTION_STRING)
db = client[DATABASE]
client.drop_database(DATABASE) # clear database when its needed

# %% [markdown]
# ### Importing data from mysql database

# %%
# Данные были зарание экспортированы из mysql в json файлы
list_of_data_files = [r"a_stop.json", r"parking.json", r"parking_type.json", r"public_vehicle.json",\
                      r"rented_vehicle.json", r"route.json", r"route_stop.json", r"sensors_data.json",\
                      r"status.json", r"stop_type.json", r"transport.json", r"transport_type.json",\
                      r"trip.json", r"trip_type.json", r"validator_s_data.json", r"vehicle_rent_status_data.json"]
list_of_data_names = ["a_stop", "parking", "parking_type", "public_vehicle", "rented_vehicle", "route", "route_stop",\
                      "sensors_data", "status", "stop_type", "transport", "transport_type", "trip", "trip_type", "validator_s_data",\
                      "vehicle_rent_status_data"]

# %%
for filepath, filename in zip(list_of_data_files, list_of_data_names):

  сollection = db[filename]
  requesting = []

  with open(filepath, 'r', encoding='utf-8') as file:
    file_data = json.load(file)
  
  if isinstance(file_data, list):
    сollection.insert_many(file_data)  
  else:
    сollection.insert_one(file_data)

# %%
db.list_collection_names()
# Out:
# ['public_vehicle',
#  'rented_vehicle',
#  'transport_type',
#  'route',
#  'transport',
#  'trip_type',
#  'route_stop',
#  'sensors_data',
#  'trip',
#  'parking_type',
#  'validator_s_data',
#  'parking',
#  'a_stop',
#  'stop_type',
#  'status',
#  'vehicle_rent_status_data']

# %%
# Данные vehicle_rent_status_data сохранились с ошибкой (поле Status_id принимает значения None). Востановим эти данные с помощью поля Card_id
print("Уникальные значения:", db.vehicle_rent_status_data.distinct("Status_id"))
# Исправление
db.vehicle_rent_status_data.update_many({"Card_id": {"$ne": None}}, {"$set": { "Status_id" : True}})
db.vehicle_rent_status_data.update_many({"Card_id": {"$eq": None}}, {"$set": { "Status_id" : False}})
print("Уникальные значения после исправления:", db.vehicle_rent_status_data.distinct("Status_id"))
# Out:
# Уникальные значения: [None]
# Уникальные значения после исправления: [False, True]

# %% [markdown]
# ### Data statistics

# %%
# print database statistics
pprint(db.command("dbstats"))
# Out:
# {'avgObjSize': 147.26402427034466,
#  'collections': 16,
#  'dataSize': 5242452.0,
#  'db': 'citytransportweb',
#  'freeStorageSize': 0.0,
#  'fsTotalSize': 510118756352.0,
#  'fsUsedSize': 434581102592.0,
#  'indexFreeStorageSize': 0.0,
#  'indexSize': 65536.0,
#  'indexes': 16,
#  'objects': 35599,
#  'ok': 1.0,
#  'scaleFactor': 1.0,
#  'storageSize': 65536.0,
#  'totalFreeStorageSize': 0.0,
#  'totalSize': 131072.0,
#  'views': 0}

# %%
# for collection in list_of_data_names:
#   # print collection statistics
#   pprint(db.command("collstats", collection))
#   break

# %% [markdown]
# ### Queries

# %%
### Query 1
### Найти все транспортные средства которые брали в аренду 25.05.2020
result = db.vehicle_rent_status_data.aggregate(
    [{"$match": {"$and": [{"Departure_waiting_time": {"$gte": '2020-05-25 00:00:00', "$lt": '2020-05-26 00:00:00'}}, {"Status_id": True}]}},
    ]
)

for doc in result:
  pprint(doc)
# Out:
# {'Average_speed': 85,
#  'Card_id': 8450221817428453,
#  'Departure_waiting_time': '2020-05-25 01:26:08',
#  'Rented_vehicle_id': 7,
#  'Status_id': True,
#  'Vehicle_id': 11,
#  '_id': ObjectId('61d0fc2e5a40174705eaf178'),
#  'id_Parking': 6}
# {'Average_speed': 74,
#  'Card_id': 8565882626516635,
#  'Departure_waiting_time': '2020-05-25 01:42:02',
#  'Rented_vehicle_id': 1,
#  'Status_id': True,
#  'Vehicle_id': 5,
#  '_id': ObjectId('61d0fc2e5a40174705eaf17b'),
#  'id_Parking': 7}
# {'Average_speed': 82,
#  'Card_id': 7778788977096592,
#  'Departure_waiting_time': '2020-05-25 02:19:39',
#  'Rented_vehicle_id': 2,
#  'Status_id': True,
#  'Vehicle_id': 6,
#  '_id': ObjectId('61d0fc2e5a40174705eaf17e'),
#  'id_Parking': 6}
# {'Average_speed': 7,
#  'Card_id': 3900947831478853,
#  'Departure_waiting_time': '2020-05-25 02:25:55',
#  'Rented_vehicle_id': 18,
#  'Status_id': True,
#  'Vehicle_id': 22,
#  '_id': ObjectId('61d0fc2e5a40174705eaf17f'),
#  'id_Parking': 12}
# {'Average_speed': 24,
#  'Card_id': 2983575090750656,
#  'Departure_waiting_time': '2020-05-25 02:29:05',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf180'),
#  'id_Parking': 15}
# {'Average_speed': 84,
#  'Card_id': 5075670614909074,
#  'Departure_waiting_time': '2020-05-25 02:36:45',
#  'Rented_vehicle_id': 5,
#  'Status_id': True,
#  'Vehicle_id': 9,
#  '_id': ObjectId('61d0fc2e5a40174705eaf182'),
#  'id_Parking': 8}
# {'Average_speed': 29,
#  'Card_id': 6876309411485036,
#  'Departure_waiting_time': '2020-05-25 02:40:31',
#  'Rented_vehicle_id': 19,
#  'Status_id': True,
#  'Vehicle_id': 23,
#  '_id': ObjectId('61d0fc2e5a40174705eaf184'),
#  'id_Parking': 14}
# {'Average_speed': 19,
#  'Card_id': 6195816395986654,
#  'Departure_waiting_time': '2020-05-25 02:52:51',
#  'Rented_vehicle_id': 23,
#  'Status_id': True,
#  'Vehicle_id': 27,
#  '_id': ObjectId('61d0fc2e5a40174705eaf185'),
#  'id_Parking': 12}
# {'Average_speed': 84,
#  'Card_id': 5307434973593275,
#  'Departure_waiting_time': '2020-05-25 03:38:45',
#  'Rented_vehicle_id': 3,
#  'Status_id': True,
#  'Vehicle_id': 7,
#  '_id': ObjectId('61d0fc2e5a40174705eaf18b'),
#  'id_Parking': 1}
# {'Average_speed': 8,
#  'Card_id': 9735428235247198,
#  'Departure_waiting_time': '2020-05-25 03:44:58',
#  'Rented_vehicle_id': 17,
#  'Status_id': True,
#  'Vehicle_id': 21,
#  '_id': ObjectId('61d0fc2e5a40174705eaf18d'),
#  'id_Parking': 13}
# {'Average_speed': 61,
#  'Card_id': 8670446835151359,
#  'Departure_waiting_time': '2020-05-25 04:06:59',
#  'Rented_vehicle_id': 8,
#  'Status_id': True,
#  'Vehicle_id': 12,
#  '_id': ObjectId('61d0fc2e5a40174705eaf190'),
#  'id_Parking': 2}
# {'Average_speed': 11,
#  'Card_id': 1282244823204581,
#  'Departure_waiting_time': '2020-05-25 04:18:06',
#  'Rented_vehicle_id': 21,
#  'Status_id': True,
#  'Vehicle_id': 25,
#  '_id': ObjectId('61d0fc2e5a40174705eaf191'),
#  'id_Parking': 12}
# {'Average_speed': 15,
#  'Card_id': 2782722453384402,
#  'Departure_waiting_time': '2020-05-25 04:23:16',
#  'Rented_vehicle_id': 16,
#  'Status_id': True,
#  'Vehicle_id': 20,
#  '_id': ObjectId('61d0fc2e5a40174705eaf192'),
#  'id_Parking': 14}
# {'Average_speed': 81,
#  'Card_id': 5371859639298040,
#  'Departure_waiting_time': '2020-05-25 04:34:56',
#  'Rented_vehicle_id': 5,
#  'Status_id': True,
#  'Vehicle_id': 9,
#  '_id': ObjectId('61d0fc2e5a40174705eaf195'),
#  'id_Parking': 5}
# {'Average_speed': 65,
#  'Card_id': 9555100783291368,
#  'Departure_waiting_time': '2020-05-25 04:38:40',
#  'Rented_vehicle_id': 1,
#  'Status_id': True,
#  'Vehicle_id': 5,
#  '_id': ObjectId('61d0fc2e5a40174705eaf196'),
#  'id_Parking': 2}
# {'Average_speed': 15,
#  'Card_id': 8574752800701887,
#  'Departure_waiting_time': '2020-05-25 04:42:44',
#  'Rented_vehicle_id': 13,
#  'Status_id': True,
#  'Vehicle_id': 17,
#  '_id': ObjectId('61d0fc2e5a40174705eaf197'),
#  'id_Parking': 13}
# {'Average_speed': 15,
#  'Card_id': 3204606757689832,
#  'Departure_waiting_time': '2020-05-25 04:43:02',
#  'Rented_vehicle_id': 12,
#  'Status_id': True,
#  'Vehicle_id': 16,
#  '_id': ObjectId('61d0fc2e5a40174705eaf198'),
#  'id_Parking': 12}
# {'Average_speed': 80,
#  'Card_id': 6186378532262871,
#  'Departure_waiting_time': '2020-05-25 04:48:40',
#  'Rented_vehicle_id': 10,
#  'Status_id': True,
#  'Vehicle_id': 14,
#  '_id': ObjectId('61d0fc2e5a40174705eaf19b'),
#  'id_Parking': 9}
# {'Average_speed': 77,
#  'Card_id': 3210317499200178,
#  'Departure_waiting_time': '2020-05-25 05:05:38',
#  'Rented_vehicle_id': 11,
#  'Status_id': True,
#  'Vehicle_id': 15,
#  '_id': ObjectId('61d0fc2e5a40174705eaf19e'),
#  'id_Parking': 7}
# {'Average_speed': 83,
#  'Card_id': 3958632164596237,
#  'Departure_waiting_time': '2020-05-25 05:25:42',
#  'Rented_vehicle_id': 8,
#  'Status_id': True,
#  'Vehicle_id': 12,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1a3'),
#  'id_Parking': 4}
# {'Average_speed': 21,
#  'Card_id': 9189246777621328,
#  'Departure_waiting_time': '2020-05-25 05:38:51',
#  'Rented_vehicle_id': 16,
#  'Status_id': True,
#  'Vehicle_id': 20,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1a7'),
#  'id_Parking': 14}
# {'Average_speed': 12,
#  'Card_id': 1319852520078283,
#  'Departure_waiting_time': '2020-05-25 05:39:17',
#  'Rented_vehicle_id': 23,
#  'Status_id': True,
#  'Vehicle_id': 27,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1a9'),
#  'id_Parking': 12}
# {'Average_speed': 8,
#  'Card_id': 7719242830499301,
#  'Departure_waiting_time': '2020-05-25 05:53:07',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1ac'),
#  'id_Parking': 13}
# {'Average_speed': 79,
#  'Card_id': 9514779864358512,
#  'Departure_waiting_time': '2020-05-25 06:00:31',
#  'Rented_vehicle_id': 9,
#  'Status_id': True,
#  'Vehicle_id': 13,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1ad'),
#  'id_Parking': 8}
# {'Average_speed': 7,
#  'Card_id': 2427991476308546,
#  'Departure_waiting_time': '2020-05-25 06:16:41',
#  'Rented_vehicle_id': 22,
#  'Status_id': True,
#  'Vehicle_id': 26,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1af'),
#  'id_Parking': 13}
# {'Average_speed': 6,
#  'Card_id': 3047483590475734,
#  'Departure_waiting_time': '2020-05-25 06:20:52',
#  'Rented_vehicle_id': 20,
#  'Status_id': True,
#  'Vehicle_id': 24,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b0'),
#  'id_Parking': 14}
# {'Average_speed': 30,
#  'Card_id': 5192997452982699,
#  'Departure_waiting_time': '2020-05-25 06:25:39',
#  'Rented_vehicle_id': 15,
#  'Status_id': True,
#  'Vehicle_id': 19,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b1'),
#  'id_Parking': 14}
# {'Average_speed': 20,
#  'Card_id': 1620891598631527,
#  'Departure_waiting_time': '2020-05-25 06:28:13',
#  'Rented_vehicle_id': 17,
#  'Status_id': True,
#  'Vehicle_id': 21,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b2'),
#  'id_Parking': 13}
# {'Average_speed': 83,
#  'Card_id': 9913794573316160,
#  'Departure_waiting_time': '2020-05-25 06:31:11',
#  'Rented_vehicle_id': 4,
#  'Status_id': True,
#  'Vehicle_id': 8,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b3'),
#  'id_Parking': 6}
# {'Average_speed': 76,
#  'Card_id': 9555746977735076,
#  'Departure_waiting_time': '2020-05-25 06:41:54',
#  'Rented_vehicle_id': 5,
#  'Status_id': True,
#  'Vehicle_id': 9,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b5'),
#  'id_Parking': 2}
# {'Average_speed': 68,
#  'Card_id': 5142689437738330,
#  'Departure_waiting_time': '2020-05-25 06:43:05',
#  'Rented_vehicle_id': 1,
#  'Status_id': True,
#  'Vehicle_id': 5,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b6'),
#  'id_Parking': 4}
# {'Average_speed': 12,
#  'Card_id': 6893848166702174,
#  'Departure_waiting_time': '2020-05-25 06:56:23',
#  'Rented_vehicle_id': 19,
#  'Status_id': True,
#  'Vehicle_id': 23,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b7'),
#  'id_Parking': 13}
# {'Average_speed': 79,
#  'Card_id': 2116664483320587,
#  'Departure_waiting_time': '2020-05-25 07:01:26',
#  'Rented_vehicle_id': 7,
#  'Status_id': True,
#  'Vehicle_id': 11,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b8'),
#  'id_Parking': 7}
# {'Average_speed': 68,
#  'Card_id': 6179158017206153,
#  'Departure_waiting_time': '2020-05-25 07:13:06',
#  'Rented_vehicle_id': 11,
#  'Status_id': True,
#  'Vehicle_id': 15,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1b9'),
#  'id_Parking': 1}
# {'Average_speed': 65,
#  'Card_id': 9441156294607704,
#  'Departure_waiting_time': '2020-05-25 07:24:48',
#  'Rented_vehicle_id': 6,
#  'Status_id': True,
#  'Vehicle_id': 10,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1bc'),
#  'id_Parking': 2}
# {'Average_speed': 23,
#  'Card_id': 6573257871506045,
#  'Departure_waiting_time': '2020-05-25 07:28:15',
#  'Rented_vehicle_id': 12,
#  'Status_id': True,
#  'Vehicle_id': 16,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1bd'),
#  'id_Parking': 11}
# {'Average_speed': 64,
#  'Card_id': 6911581172525493,
#  'Departure_waiting_time': '2020-05-25 07:29:32',
#  'Rented_vehicle_id': 2,
#  'Status_id': True,
#  'Vehicle_id': 6,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1be'),
#  'id_Parking': 8}
# {'Average_speed': 8,
#  'Card_id': 5126356167836446,
#  'Departure_waiting_time': '2020-05-25 08:14:27',
#  'Rented_vehicle_id': 23,
#  'Status_id': True,
#  'Vehicle_id': 27,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1c8'),
#  'id_Parking': 15}
# {'Average_speed': 9,
#  'Card_id': 5546673215503500,
#  'Departure_waiting_time': '2020-05-25 08:19:18',
#  'Rented_vehicle_id': 13,
#  'Status_id': True,
#  'Vehicle_id': 17,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1c9'),
#  'id_Parking': 13}
# {'Average_speed': 83,
#  'Card_id': 8851674201760138,
#  'Departure_waiting_time': '2020-05-25 08:20:44',
#  'Rented_vehicle_id': 9,
#  'Status_id': True,
#  'Vehicle_id': 13,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1cb'),
#  'id_Parking': 1}
# {'Average_speed': 61,
#  'Card_id': 1870386096528159,
#  'Departure_waiting_time': '2020-05-25 08:30:10',
#  'Rented_vehicle_id': 3,
#  'Status_id': True,
#  'Vehicle_id': 7,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1cc'),
#  'id_Parking': 4}
# {'Average_speed': 62,
#  'Card_id': 4734098840257245,
#  'Departure_waiting_time': '2020-05-25 08:39:02',
#  'Rented_vehicle_id': 4,
#  'Status_id': True,
#  'Vehicle_id': 8,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1ce'),
#  'id_Parking': 8}
# {'Average_speed': 19,
#  'Card_id': 2971265536706211,
#  'Departure_waiting_time': '2020-05-25 08:55:29',
#  'Rented_vehicle_id': 22,
#  'Status_id': True,
#  'Vehicle_id': 26,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1d0'),
#  'id_Parking': 13}
# {'Average_speed': 13,
#  'Card_id': 8807344428084180,
#  'Departure_waiting_time': '2020-05-25 08:56:15',
#  'Rented_vehicle_id': 20,
#  'Status_id': True,
#  'Vehicle_id': 24,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1d1'),
#  'id_Parking': 12}
# {'Average_speed': 27,
#  'Card_id': 8961710594558819,
#  'Departure_waiting_time': '2020-05-25 09:02:17',
#  'Rented_vehicle_id': 18,
#  'Status_id': True,
#  'Vehicle_id': 22,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1d2'),
#  'id_Parking': 15}
# {'Average_speed': 6,
#  'Card_id': 8375899875886645,
#  'Departure_waiting_time': '2020-05-25 09:24:59',
#  'Rented_vehicle_id': 21,
#  'Status_id': True,
#  'Vehicle_id': 25,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1d3'),
#  'id_Parking': 15}
# {'Average_speed': 89,
#  'Card_id': 8421143344064377,
#  'Departure_waiting_time': '2020-05-25 09:30:37',
#  'Rented_vehicle_id': 5,
#  'Status_id': True,
#  'Vehicle_id': 9,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1d4'),
#  'id_Parking': 1}
# {'Average_speed': 13,
#  'Card_id': 6525760517945290,
#  'Departure_waiting_time': '2020-05-25 09:47:38',
#  'Rented_vehicle_id': 19,
#  'Status_id': True,
#  'Vehicle_id': 23,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1d6'),
#  'id_Parking': 11}
# {'Average_speed': 74,
#  'Card_id': 6654149456558888,
#  'Departure_waiting_time': '2020-05-25 09:51:28',
#  'Rented_vehicle_id': 6,
#  'Status_id': True,
#  'Vehicle_id': 10,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1db'),
#  'id_Parking': 7}
# {'Average_speed': 22,
#  'Card_id': 3052454821814275,
#  'Departure_waiting_time': '2020-05-25 10:01:17',
#  'Rented_vehicle_id': 17,
#  'Status_id': True,
#  'Vehicle_id': 21,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1de'),
#  'id_Parking': 12}
# {'Average_speed': 21,
#  'Card_id': 6030641396558510,
#  'Departure_waiting_time': '2020-05-25 10:16:53',
#  'Rented_vehicle_id': 12,
#  'Status_id': True,
#  'Vehicle_id': 16,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1e1'),
#  'id_Parking': 11}
# {'Average_speed': 70,
#  'Card_id': 2308720095370635,
#  'Departure_waiting_time': '2020-05-25 10:31:54',
#  'Rented_vehicle_id': 10,
#  'Status_id': True,
#  'Vehicle_id': 14,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1e2'),
#  'id_Parking': 7}
# {'Average_speed': 8,
#  'Card_id': 6433082837083454,
#  'Departure_waiting_time': '2020-05-25 11:01:49',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1e3'),
#  'id_Parking': 13}
# {'Average_speed': 29,
#  'Card_id': 3927905867740424,
#  'Departure_waiting_time': '2020-05-25 11:07:43',
#  'Rented_vehicle_id': 16,
#  'Status_id': True,
#  'Vehicle_id': 20,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1e6'),
#  'id_Parking': 15}
# {'Average_speed': 79,
#  'Card_id': 8952236495867592,
#  'Departure_waiting_time': '2020-05-25 11:25:33',
#  'Rented_vehicle_id': 11,
#  'Status_id': True,
#  'Vehicle_id': 15,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1ea'),
#  'id_Parking': 6}
# {'Average_speed': 17,
#  'Card_id': 1229982307394950,
#  'Departure_waiting_time': '2020-05-25 11:25:52',
#  'Rented_vehicle_id': 15,
#  'Status_id': True,
#  'Vehicle_id': 19,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1eb'),
#  'id_Parking': 14}
# {'Average_speed': 21,
#  'Card_id': 6685307354373213,
#  'Departure_waiting_time': '2020-05-25 11:31:11',
#  'Rented_vehicle_id': 23,
#  'Status_id': True,
#  'Vehicle_id': 27,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1ec'),
#  'id_Parking': 12}
# {'Average_speed': 71,
#  'Card_id': 9200477304123788,
#  'Departure_waiting_time': '2020-05-25 11:33:35',
#  'Rented_vehicle_id': 7,
#  'Status_id': True,
#  'Vehicle_id': 11,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1ed'),
#  'id_Parking': 4}
# {'Average_speed': 20,
#  'Card_id': 4446615436530314,
#  'Departure_waiting_time': '2020-05-25 11:37:27',
#  'Rented_vehicle_id': 21,
#  'Status_id': True,
#  'Vehicle_id': 25,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1ee'),
#  'id_Parking': 11}
# {'Average_speed': 79,
#  'Card_id': 8351626219555387,
#  'Departure_waiting_time': '2020-05-25 11:42:20',
#  'Rented_vehicle_id': 3,
#  'Status_id': True,
#  'Vehicle_id': 7,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1f0'),
#  'id_Parking': 2}
# {'Average_speed': 80,
#  'Card_id': 3158509944713218,
#  'Departure_waiting_time': '2020-05-25 11:59:24',
#  'Rented_vehicle_id': 2,
#  'Status_id': True,
#  'Vehicle_id': 6,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1f2'),
#  'id_Parking': 3}
# {'Average_speed': 19,
#  'Card_id': 6875909795869058,
#  'Departure_waiting_time': '2020-05-25 12:03:34',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1f3'),
#  'id_Parking': 13}
# {'Average_speed': 87,
#  'Card_id': 1840254269391535,
#  'Departure_waiting_time': '2020-05-25 12:37:33',
#  'Rented_vehicle_id': 1,
#  'Status_id': True,
#  'Vehicle_id': 5,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1f8'),
#  'id_Parking': 7}
# {'Average_speed': 20,
#  'Card_id': 4934721620692612,
#  'Departure_waiting_time': '2020-05-25 12:47:18',
#  'Rented_vehicle_id': 13,
#  'Status_id': True,
#  'Vehicle_id': 17,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1fb'),
#  'id_Parking': 13}
# {'Average_speed': 24,
#  'Card_id': 1342878572030811,
#  'Departure_waiting_time': '2020-05-25 12:53:11',
#  'Rented_vehicle_id': 20,
#  'Status_id': True,
#  'Vehicle_id': 24,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1fc'),
#  'id_Parking': 15}
# {'Average_speed': 79,
#  'Card_id': 8725527103734693,
#  'Departure_waiting_time': '2020-05-25 12:55:58',
#  'Rented_vehicle_id': 8,
#  'Status_id': True,
#  'Vehicle_id': 12,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1fd'),
#  'id_Parking': 4}
# {'Average_speed': 6,
#  'Card_id': 1807729752555238,
#  'Departure_waiting_time': '2020-05-25 13:00:14',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf1fe'),
#  'id_Parking': 13}
# {'Average_speed': 8,
#  'Card_id': 3646863110034599,
#  'Departure_waiting_time': '2020-05-25 13:06:01',
#  'Rented_vehicle_id': 22,
#  'Status_id': True,
#  'Vehicle_id': 26,
#  '_id': ObjectId('61d0fc2e5a40174705eaf201'),
#  'id_Parking': 11}
# {'Average_speed': 22,
#  'Card_id': 9226017323533088,
#  'Departure_waiting_time': '2020-05-25 13:21:09',
#  'Rented_vehicle_id': 18,
#  'Status_id': True,
#  'Vehicle_id': 22,
#  '_id': ObjectId('61d0fc2e5a40174705eaf202'),
#  'id_Parking': 13}
# {'Average_speed': 11,
#  'Card_id': 9411437686915916,
#  'Departure_waiting_time': '2020-05-25 13:26:27',
#  'Rented_vehicle_id': 16,
#  'Status_id': True,
#  'Vehicle_id': 20,
#  '_id': ObjectId('61d0fc2e5a40174705eaf204'),
#  'id_Parking': 15}
# {'Average_speed': 76,
#  'Card_id': 5739258446487839,
#  'Departure_waiting_time': '2020-05-25 13:38:18',
#  'Rented_vehicle_id': 9,
#  'Status_id': True,
#  'Vehicle_id': 13,
#  '_id': ObjectId('61d0fc2e5a40174705eaf206'),
#  'id_Parking': 1}
# {'Average_speed': 61,
#  'Card_id': 7044380165677872,
#  'Departure_waiting_time': '2020-05-25 14:04:00',
#  'Rented_vehicle_id': 5,
#  'Status_id': True,
#  'Vehicle_id': 9,
#  '_id': ObjectId('61d0fc2e5a40174705eaf209'),
#  'id_Parking': 2}
# {'Average_speed': 81,
#  'Card_id': 9436549726348882,
#  'Departure_waiting_time': '2020-05-25 14:10:46',
#  'Rented_vehicle_id': 4,
#  'Status_id': True,
#  'Vehicle_id': 8,
#  '_id': ObjectId('61d0fc2e5a40174705eaf20c'),
#  'id_Parking': 6}
# {'Average_speed': 75,
#  'Card_id': 8453391509552850,
#  'Departure_waiting_time': '2020-05-25 14:24:30',
#  'Rented_vehicle_id': 11,
#  'Status_id': True,
#  'Vehicle_id': 15,
#  '_id': ObjectId('61d0fc2e5a40174705eaf20e'),
#  'id_Parking': 7}
# {'Average_speed': 28,
#  'Card_id': 4220465108957575,
#  'Departure_waiting_time': '2020-05-25 14:38:30',
#  'Rented_vehicle_id': 18,
#  'Status_id': True,
#  'Vehicle_id': 22,
#  '_id': ObjectId('61d0fc2e5a40174705eaf210'),
#  'id_Parking': 12}
# {'Average_speed': 10,
#  'Card_id': 6274753581057073,
#  'Departure_waiting_time': '2020-05-25 14:50:02',
#  'Rented_vehicle_id': 19,
#  'Status_id': True,
#  'Vehicle_id': 23,
#  '_id': ObjectId('61d0fc2e5a40174705eaf211'),
#  'id_Parking': 12}
# {'Average_speed': 28,
#  'Card_id': 8591523932843957,
#  'Departure_waiting_time': '2020-05-25 14:52:07',
#  'Rented_vehicle_id': 17,
#  'Status_id': True,
#  'Vehicle_id': 21,
#  '_id': ObjectId('61d0fc2e5a40174705eaf213'),
#  'id_Parking': 13}
# {'Average_speed': 29,
#  'Card_id': 8192104101359941,
#  'Departure_waiting_time': '2020-05-25 14:54:09',
#  'Rented_vehicle_id': 21,
#  'Status_id': True,
#  'Vehicle_id': 25,
#  '_id': ObjectId('61d0fc2e5a40174705eaf214'),
#  'id_Parking': 12}
# {'Average_speed': 19,
#  'Card_id': 5306351243803605,
#  'Departure_waiting_time': '2020-05-25 15:00:47',
#  'Rented_vehicle_id': 23,
#  'Status_id': True,
#  'Vehicle_id': 27,
#  '_id': ObjectId('61d0fc2e5a40174705eaf217'),
#  'id_Parking': 14}
# {'Average_speed': 22,
#  'Card_id': 8588421178598349,
#  'Departure_waiting_time': '2020-05-25 15:06:25',
#  'Rented_vehicle_id': 15,
#  'Status_id': True,
#  'Vehicle_id': 19,
#  '_id': ObjectId('61d0fc2e5a40174705eaf218'),
#  'id_Parking': 12}
# {'Average_speed': 23,
#  'Card_id': 3298142385015397,
#  'Departure_waiting_time': '2020-05-25 15:35:34',
#  'Rented_vehicle_id': 12,
#  'Status_id': True,
#  'Vehicle_id': 16,
#  '_id': ObjectId('61d0fc2e5a40174705eaf21c'),
#  'id_Parking': 11}
# {'Average_speed': 70,
#  'Card_id': 8182117030194138,
#  'Departure_waiting_time': '2020-05-25 16:06:48',
#  'Rented_vehicle_id': 7,
#  'Status_id': True,
#  'Vehicle_id': 11,
#  '_id': ObjectId('61d0fc2e5a40174705eaf21e'),
#  'id_Parking': 9}
# {'Average_speed': 68,
#  'Card_id': 7353705711060861,
#  'Departure_waiting_time': '2020-05-25 16:07:00',
#  'Rented_vehicle_id': 8,
#  'Status_id': True,
#  'Vehicle_id': 12,
#  '_id': ObjectId('61d0fc2e5a40174705eaf21f'),
#  'id_Parking': 7}
# {'Average_speed': 88,
#  'Card_id': 4675954164635347,
#  'Departure_waiting_time': '2020-05-25 16:19:30',
#  'Rented_vehicle_id': 1,
#  'Status_id': True,
#  'Vehicle_id': 5,
#  '_id': ObjectId('61d0fc2e5a40174705eaf221'),
#  'id_Parking': 3}
# {'Average_speed': 77,
#  'Card_id': 2362987780350249,
#  'Departure_waiting_time': '2020-05-25 16:31:15',
#  'Rented_vehicle_id': 2,
#  'Status_id': True,
#  'Vehicle_id': 6,
#  '_id': ObjectId('61d0fc2e5a40174705eaf222'),
#  'id_Parking': 9}
# {'Average_speed': 67,
#  'Card_id': 3188062263827829,
#  'Departure_waiting_time': '2020-05-25 16:33:18',
#  'Rented_vehicle_id': 4,
#  'Status_id': True,
#  'Vehicle_id': 8,
#  '_id': ObjectId('61d0fc2e5a40174705eaf223'),
#  'id_Parking': 5}
# {'Average_speed': 87,
#  'Card_id': 1631065955041969,
#  'Departure_waiting_time': '2020-05-25 16:34:40',
#  'Rented_vehicle_id': 6,
#  'Status_id': True,
#  'Vehicle_id': 10,
#  '_id': ObjectId('61d0fc2e5a40174705eaf224'),
#  'id_Parking': 7}
# {'Average_speed': 65,
#  'Card_id': 2910078330813049,
#  'Departure_waiting_time': '2020-05-25 16:45:24',
#  'Rented_vehicle_id': 3,
#  'Status_id': True,
#  'Vehicle_id': 7,
#  '_id': ObjectId('61d0fc2e5a40174705eaf226'),
#  'id_Parking': 5}
# {'Average_speed': 8,
#  'Card_id': 4354883435512784,
#  'Departure_waiting_time': '2020-05-25 17:16:46',
#  'Rented_vehicle_id': 20,
#  'Status_id': True,
#  'Vehicle_id': 24,
#  '_id': ObjectId('61d0fc2e5a40174705eaf229'),
#  'id_Parking': 13}
# {'Average_speed': 14,
#  'Card_id': 6942273422090591,
#  'Departure_waiting_time': '2020-05-25 17:46:41',
#  'Rented_vehicle_id': 22,
#  'Status_id': True,
#  'Vehicle_id': 26,
#  '_id': ObjectId('61d0fc2e5a40174705eaf22c'),
#  'id_Parking': 12}
# {'Average_speed': 70,
#  'Card_id': 7269328603771821,
#  'Departure_waiting_time': '2020-05-25 17:59:09',
#  'Rented_vehicle_id': 10,
#  'Status_id': True,
#  'Vehicle_id': 14,
#  '_id': ObjectId('61d0fc2e5a40174705eaf22e'),
#  'id_Parking': 3}
# {'Average_speed': 8,
#  'Card_id': 2563286080549737,
#  'Departure_waiting_time': '2020-05-25 18:09:50',
#  'Rented_vehicle_id': 23,
#  'Status_id': True,
#  'Vehicle_id': 27,
#  '_id': ObjectId('61d0fc2e5a40174705eaf234'),
#  'id_Parking': 13}
# {'Average_speed': 79,
#  'Card_id': 7465161730037221,
#  'Departure_waiting_time': '2020-05-25 18:17:20',
#  'Rented_vehicle_id': 9,
#  'Status_id': True,
#  'Vehicle_id': 13,
#  '_id': ObjectId('61d0fc2e5a40174705eaf237'),
#  'id_Parking': 7}
# {'Average_speed': 8,
#  'Card_id': 9748967389342344,
#  'Departure_waiting_time': '2020-05-25 18:25:18',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf238'),
#  'id_Parking': 13}
# {'Average_speed': 17,
#  'Card_id': 9134916027202192,
#  'Departure_waiting_time': '2020-05-25 18:34:05',
#  'Rented_vehicle_id': 18,
#  'Status_id': True,
#  'Vehicle_id': 22,
#  '_id': ObjectId('61d0fc2e5a40174705eaf239'),
#  'id_Parking': 11}
# {'Average_speed': 26,
#  'Card_id': 6105482773022245,
#  'Departure_waiting_time': '2020-05-25 18:35:34',
#  'Rented_vehicle_id': 22,
#  'Status_id': True,
#  'Vehicle_id': 26,
#  '_id': ObjectId('61d0fc2e5a40174705eaf23b'),
#  'id_Parking': 13}
# {'Average_speed': 66,
#  'Card_id': 2594161139423178,
#  'Departure_waiting_time': '2020-05-25 18:35:41',
#  'Rented_vehicle_id': 1,
#  'Status_id': True,
#  'Vehicle_id': 5,
#  '_id': ObjectId('61d0fc2e5a40174705eaf23c'),
#  'id_Parking': 3}
# {'Average_speed': 24,
#  'Card_id': 9906485168176224,
#  'Departure_waiting_time': '2020-05-25 18:53:03',
#  'Rented_vehicle_id': 13,
#  'Status_id': True,
#  'Vehicle_id': 17,
#  '_id': ObjectId('61d0fc2e5a40174705eaf23d'),
#  'id_Parking': 14}
# {'Average_speed': 89,
#  'Card_id': 1456021440640112,
#  'Departure_waiting_time': '2020-05-25 19:09:32',
#  'Rented_vehicle_id': 2,
#  'Status_id': True,
#  'Vehicle_id': 6,
#  '_id': ObjectId('61d0fc2e5a40174705eaf23f'),
#  'id_Parking': 4}
# {'Average_speed': 12,
#  'Card_id': 8133356155020517,
#  'Departure_waiting_time': '2020-05-25 19:24:39',
#  'Rented_vehicle_id': 20,
#  'Status_id': True,
#  'Vehicle_id': 24,
#  '_id': ObjectId('61d0fc2e5a40174705eaf244'),
#  'id_Parking': 12}
# {'Average_speed': 69,
#  'Card_id': 5600236669741791,
#  'Departure_waiting_time': '2020-05-25 19:36:59',
#  'Rented_vehicle_id': 8,
#  'Status_id': True,
#  'Vehicle_id': 12,
#  '_id': ObjectId('61d0fc2e5a40174705eaf246'),
#  'id_Parking': 6}
# {'Average_speed': 78,
#  'Card_id': 4846831205158337,
#  'Departure_waiting_time': '2020-05-25 19:39:05',
#  'Rented_vehicle_id': 5,
#  'Status_id': True,
#  'Vehicle_id': 9,
#  '_id': ObjectId('61d0fc2e5a40174705eaf247'),
#  'id_Parking': 4}
# {'Average_speed': 77,
#  'Card_id': 4578791394437469,
#  'Departure_waiting_time': '2020-05-25 19:40:19',
#  'Rented_vehicle_id': 10,
#  'Status_id': True,
#  'Vehicle_id': 14,
#  '_id': ObjectId('61d0fc2e5a40174705eaf248'),
#  'id_Parking': 3}
# {'Average_speed': 87,
#  'Card_id': 9568272307113068,
#  'Departure_waiting_time': '2020-05-25 19:42:17',
#  'Rented_vehicle_id': 7,
#  'Status_id': True,
#  'Vehicle_id': 11,
#  '_id': ObjectId('61d0fc2e5a40174705eaf249'),
#  'id_Parking': 1}
# {'Average_speed': 88,
#  'Card_id': 9871150266259116,
#  'Departure_waiting_time': '2020-05-25 19:42:50',
#  'Rented_vehicle_id': 6,
#  'Status_id': True,
#  'Vehicle_id': 10,
#  '_id': ObjectId('61d0fc2e5a40174705eaf24b'),
#  'id_Parking': 2}
# {'Average_speed': 9,
#  'Card_id': 2938542419055982,
#  'Departure_waiting_time': '2020-05-25 19:44:02',
#  'Rented_vehicle_id': 15,
#  'Status_id': True,
#  'Vehicle_id': 19,
#  '_id': ObjectId('61d0fc2e5a40174705eaf24c'),
#  'id_Parking': 13}
# {'Average_speed': 26,
#  'Card_id': 6694680417603516,
#  'Departure_waiting_time': '2020-05-25 19:46:18',
#  'Rented_vehicle_id': 16,
#  'Status_id': True,
#  'Vehicle_id': 20,
#  '_id': ObjectId('61d0fc2e5a40174705eaf24d'),
#  'id_Parking': 14}
# {'Average_speed': 27,
#  'Card_id': 6037609448691466,
#  'Departure_waiting_time': '2020-05-25 20:01:22',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf24e'),
#  'id_Parking': 12}
# {'Average_speed': 11,
#  'Card_id': 1511527400940216,
#  'Departure_waiting_time': '2020-05-25 20:04:59',
#  'Rented_vehicle_id': 21,
#  'Status_id': True,
#  'Vehicle_id': 25,
#  '_id': ObjectId('61d0fc2e5a40174705eaf24f'),
#  'id_Parking': 13}
# {'Average_speed': 6,
#  'Card_id': 3380702890810280,
#  'Departure_waiting_time': '2020-05-25 20:19:12',
#  'Rented_vehicle_id': 20,
#  'Status_id': True,
#  'Vehicle_id': 24,
#  '_id': ObjectId('61d0fc2e5a40174705eaf254'),
#  'id_Parking': 11}
# {'Average_speed': 90,
#  'Card_id': 5199929144419664,
#  'Departure_waiting_time': '2020-05-25 20:34:34',
#  'Rented_vehicle_id': 4,
#  'Status_id': True,
#  'Vehicle_id': 8,
#  '_id': ObjectId('61d0fc2e5a40174705eaf258'),
#  'id_Parking': 4}
# {'Average_speed': 10,
#  'Card_id': 3032705532417358,
#  'Departure_waiting_time': '2020-05-25 20:44:24',
#  'Rented_vehicle_id': 15,
#  'Status_id': True,
#  'Vehicle_id': 19,
#  '_id': ObjectId('61d0fc2e5a40174705eaf259'),
#  'id_Parking': 13}
# {'Average_speed': 88,
#  'Card_id': 4043667536269564,
#  'Departure_waiting_time': '2020-05-25 21:02:23',
#  'Rented_vehicle_id': 11,
#  'Status_id': True,
#  'Vehicle_id': 15,
#  '_id': ObjectId('61d0fc2e5a40174705eaf25c'),
#  'id_Parking': 9}
# {'Average_speed': 26,
#  'Card_id': 9259590542185670,
#  'Departure_waiting_time': '2020-05-25 21:14:52',
#  'Rented_vehicle_id': 17,
#  'Status_id': True,
#  'Vehicle_id': 21,
#  '_id': ObjectId('61d0fc2e5a40174705eaf25f'),
#  'id_Parking': 11}
# {'Average_speed': 60,
#  'Card_id': 1472247967005007,
#  'Departure_waiting_time': '2020-05-25 21:18:39',
#  'Rented_vehicle_id': 10,
#  'Status_id': True,
#  'Vehicle_id': 14,
#  '_id': ObjectId('61d0fc2e5a40174705eaf260'),
#  'id_Parking': 2}
# {'Average_speed': 28,
#  'Card_id': 4144369162753568,
#  'Departure_waiting_time': '2020-05-25 21:25:14',
#  'Rented_vehicle_id': 13,
#  'Status_id': True,
#  'Vehicle_id': 17,
#  '_id': ObjectId('61d0fc2e5a40174705eaf261'),
#  'id_Parking': 12}
# {'Average_speed': 28,
#  'Card_id': 1828495859008744,
#  'Departure_waiting_time': '2020-05-25 21:33:29',
#  'Rented_vehicle_id': 12,
#  'Status_id': True,
#  'Vehicle_id': 16,
#  '_id': ObjectId('61d0fc2e5a40174705eaf264'),
#  'id_Parking': 11}
# {'Average_speed': 22,
#  'Card_id': 7308361207422206,
#  'Departure_waiting_time': '2020-05-25 21:36:09',
#  'Rented_vehicle_id': 19,
#  'Status_id': True,
#  'Vehicle_id': 23,
#  '_id': ObjectId('61d0fc2e5a40174705eaf265'),
#  'id_Parking': 13}
# {'Average_speed': 11,
#  'Card_id': 8591903306163758,
#  'Departure_waiting_time': '2020-05-25 21:56:13',
#  'Rented_vehicle_id': 15,
#  'Status_id': True,
#  'Vehicle_id': 19,
#  '_id': ObjectId('61d0fc2e5a40174705eaf267'),
#  'id_Parking': 13}
# {'Average_speed': 11,
#  'Card_id': 6477906296474772,
#  'Departure_waiting_time': '2020-05-25 22:13:55',
#  'Rented_vehicle_id': 22,
#  'Status_id': True,
#  'Vehicle_id': 26,
#  '_id': ObjectId('61d0fc2e5a40174705eaf268'),
#  'id_Parking': 14}
# {'Average_speed': 72,
#  'Card_id': 1274061856115294,
#  'Departure_waiting_time': '2020-05-25 22:17:47',
#  'Rented_vehicle_id': 6,
#  'Status_id': True,
#  'Vehicle_id': 10,
#  '_id': ObjectId('61d0fc2e5a40174705eaf269'),
#  'id_Parking': 9}
# {'Average_speed': 78,
#  'Card_id': 7998484727925142,
#  'Departure_waiting_time': '2020-05-25 22:21:29',
#  'Rented_vehicle_id': 9,
#  'Status_id': True,
#  'Vehicle_id': 13,
#  '_id': ObjectId('61d0fc2e5a40174705eaf26a'),
#  'id_Parking': 2}
# {'Average_speed': 88,
#  'Card_id': 4023126685082099,
#  'Departure_waiting_time': '2020-05-25 22:47:25',
#  'Rented_vehicle_id': 3,
#  'Status_id': True,
#  'Vehicle_id': 7,
#  '_id': ObjectId('61d0fc2e5a40174705eaf26c'),
#  'id_Parking': 9}
# {'Average_speed': 6,
#  'Card_id': 2932580245595966,
#  'Departure_waiting_time': '2020-05-25 22:59:39',
#  'Rented_vehicle_id': 13,
#  'Status_id': True,
#  'Vehicle_id': 17,
#  '_id': ObjectId('61d0fc2e5a40174705eaf26f'),
#  'id_Parking': 15}
# {'Average_speed': 8,
#  'Card_id': 8618556073511537,
#  'Departure_waiting_time': '2020-05-25 23:28:20',
#  'Rented_vehicle_id': 14,
#  'Status_id': True,
#  'Vehicle_id': 18,
#  '_id': ObjectId('61d0fc2e5a40174705eaf273'),
#  'id_Parking': 14}
# {'Average_speed': 23,
#  'Card_id': 6368078135296775,
#  'Departure_waiting_time': '2020-05-25 23:33:29',
#  'Rented_vehicle_id': 18,
#  'Status_id': True,
#  'Vehicle_id': 22,
#  '_id': ObjectId('61d0fc2e5a40174705eaf275'),
#  'id_Parking': 15}
# {'Average_speed': 16,
#  'Card_id': 3444145163934813,
#  'Departure_waiting_time': '2020-05-25 23:49:20',
#  'Rented_vehicle_id': 16,
#  'Status_id': True,
#  'Vehicle_id': 20,
#  '_id': ObjectId('61d0fc2e5a40174705eaf277'),
#  'id_Parking': 11}

# %%
### Query 2
### Вывести уникальные номера карт по которым средняя скорость арендованного транспортного средства
### больше либо равна 85 км/ч
result = db.vehicle_rent_status_data.aggregate(
    [{"$match": {"Average_speed": {"$gte": 85}}},
     {"$project": {"_id": 0, "Card_id": 1}},
     {"$group": {"_id": None, "Card_id": {"$addToSet": "$Card_id"}}},
     {"$unwind": "$Card_id" },
     {"$project": {"_id": 0 }},
    ]
)

for doc in result:
  pprint(doc)
# Out:
# {'Card_id': 5432211932197410}
# {'Card_id': 9114176625492216}
# {'Card_id': 1725898220879862}
# {'Card_id': 7779737422968947}
# {'Card_id': 8969212414668139}
# {'Card_id': 4675954164635347}
# {'Card_id': 8482208593266279}
# {'Card_id': 4914853618400966}
# {'Card_id': 6491526344317502}
# {'Card_id': 4525254644942707}
# {'Card_id': 5199929144419664}
# {'Card_id': 4737889807427200}
# {'Card_id': 4043667536269564}
# {'Card_id': 9370794525715332}
# {'Card_id': 9682258487383144}
# {'Card_id': 7266881448465289}
# {'Card_id': 3752081031680182}
# {'Card_id': 9678177036976606}
# {'Card_id': 1456021440640112}
# {'Card_id': 4173454651770605}
# {'Card_id': 4616000909000636}
# {'Card_id': 2149400198971294}
# {'Card_id': 6458926390352590}
# {'Card_id': 3523013776655322}
# {'Card_id': 1944014343380941}
# {'Card_id': 8728682035327593}
# {'Card_id': 3479625106304534}
# {'Card_id': 8858153974505284}
# {'Card_id': 7673424858295755}
# {'Card_id': 4609024382763565}
# {'Card_id': 1631065955041969}
# {'Card_id': 9316393769640842}
# {'Card_id': 2433299760737735}
# {'Card_id': 2461402203386093}
# {'Card_id': 3884375777919195}
# {'Card_id': 8760042984746436}
# {'Card_id': 6235503064687833}
# {'Card_id': 6161679661983326}
# {'Card_id': 1840254269391535}
# {'Card_id': 7798640483802781}
# {'Card_id': 2361430581995687}
# {'Card_id': 2134279304309077}
# {'Card_id': 8669747608406234}
# {'Card_id': 6937149656877993}
# {'Card_id': 9871150266259116}
# {'Card_id': 6948567518916510}
# {'Card_id': 7117474644554290}
# {'Card_id': 3475432411279000}
# {'Card_id': 6722319198513701}
# {'Card_id': 1561842909606027}
# {'Card_id': 9187631718989120}
# {'Card_id': 6435987015660840}
# {'Card_id': 8682134032884738}
# {'Card_id': 3554585547702932}
# {'Card_id': 5241967414731130}
# {'Card_id': 8370876567783651}
# {'Card_id': 6393736414978035}
# {'Card_id': 4023126685082099}
# {'Card_id': 3511838746733813}
# {'Card_id': 4820988909174678}
# {'Card_id': 9568272307113068}
# {'Card_id': 3249494866700372}
# {'Card_id': 3706893940183235}
# {'Card_id': 2366975739008724}
# {'Card_id': 8421143344064377}
# {'Card_id': 9959161406344884}
# {'Card_id': 1977062117287015}
# {'Card_id': 7235966156456588}
# {'Card_id': 3500128339510530}
# {'Card_id': 4997442312536242}
# {'Card_id': 9905878351913652}
# {'Card_id': 8450221817428453}

# %%
### Query 3
### Выбрать топ 3 парковок по вместимости для каждого типа транспорта.
f_part = db.parking.aggregate(
    [{"$group" : {"_id": "$Transport_type_id"}},
     {"$sort" : {"_id": ASCENDING}}
     ]
)
for doc in f_part:
  s_part = db.parking.aggregate(
      [{"$match": {"Transport_type_id": doc['_id']}},
       {"$project": {"_id": 0, "id_Parking": 1, "Parking_address": 1, "Capacity": 1, "Transport_type_id": 1}},
       {"$sort": {"Capacity": DESCENDING}},
       {"$limit": 3}
      ]
  )
  for sdoc in s_part:
    print(sdoc)
# Out:
# {'id_Parking': 19, 'Parking_address': 'Русаковская набережная, 1с2', 'Capacity': 16, 'Transport_type_id': 0}
# {'id_Parking': 20, 'Parking_address': 'Сельскохозяйственная улица, 9с3', 'Capacity': 14, 'Transport_type_id': 0}
# {'id_Parking': 21, 'Parking_address': 'Анненская ул., 25', 'Capacity': 825, 'Transport_type_id': 1}
# {'id_Parking': 23, 'Parking_address': 'Москва, Ленинградское шоссе, д.4', 'Capacity': 810, 'Transport_type_id': 1}
# {'id_Parking': 22, 'Parking_address': 'ул. Ходынская, вл. 5', 'Capacity': 680, 'Transport_type_id': 1}
# {'id_Parking': 17, 'Parking_address': 'Варшавское шоссе, 95', 'Capacity': 15, 'Transport_type_id': 4}
# {'id_Parking': 18, 'Parking_address': 'Рязанский проспект, 105', 'Capacity': 14, 'Transport_type_id': 4}
# {'id_Parking': 16, 'Parking_address': 'Бесединское ш., 17, стр. 1', 'Capacity': 12, 'Transport_type_id': 4}
# {'id_Parking': 2, 'Parking_address': 'ул. Щепкина, 49', 'Capacity': 1684, 'Transport_type_id': 5}
# {'id_Parking': 3, 'Parking_address': 'ул. Гиляровского, 37, корп. 2', 'Capacity': 58, 'Transport_type_id': 5}
# {'id_Parking': 9, 'Parking_address': 'Шереметьевская улица, 41с1', 'Capacity': 54, 'Transport_type_id': 5}
# {'id_Parking': 11, 'Parking_address': 'Шереметьевская ул., 2, стр. 2', 'Capacity': 20, 'Transport_type_id': 6}
# {'id_Parking': 12, 'Parking_address': 'улица Образцова, 11', 'Capacity': 20, 'Transport_type_id': 6}
# {'id_Parking': 13, 'Parking_address': 'улица Советской Армии, 2с1', 'Capacity': 20, 'Transport_type_id': 6}
# {'id_Parking': 10, 'Parking_address': 'Московская обл., Ленинградское ш., 75-й км', 'Capacity': 60, 'Transport_type_id': 7}

# %%
### Query 4
### Выбрать топ 3 транспортных средства с наибольшим количеством данных валидатора для каждого типа транспорта.
f_part = db.transport.aggregate(
    [{"$group" : {"_id": "$Transport_type_id"}},
     {"$sort" : {"_id": ASCENDING}}
     ]
)
for transport_type_doc in f_part:
  test = db.transport.aggregate(
          [{"$lookup":{
              "from": "validator_s_data",
              "localField": "Vehicle_id",
              "foreignField": "Vehicle_id",
              "as" : "valisators_data"
          }},
          {"$match": {"Transport_type_id": transport_type_doc['_id']}},
          {"$project": {"_id": 0, "Vehicle_id": 1, "VCOUNT": { "$size":"$valisators_data" }, "Transport_type_id": 1}},
          {"$sort": {"VCOUNT": DESCENDING}},
          {"$limit": 3}
          ])
  for doc in test:
    pprint(doc)
# Out:
# {'Transport_type_id': 1, 'VCOUNT': 8015, 'Vehicle_id': 4}
# {'Transport_type_id': 1, 'VCOUNT': 7923, 'Vehicle_id': 2}
# {'Transport_type_id': 1, 'VCOUNT': 7800, 'Vehicle_id': 3}
# {'Transport_type_id': 5, 'VCOUNT': 0, 'Vehicle_id': 5}
# {'Transport_type_id': 5, 'VCOUNT': 0, 'Vehicle_id': 6}
# {'Transport_type_id': 5, 'VCOUNT': 0, 'Vehicle_id': 7}
# {'Transport_type_id': 6, 'VCOUNT': 0, 'Vehicle_id': 16}
# {'Transport_type_id': 6, 'VCOUNT': 0, 'Vehicle_id': 17}
# {'Transport_type_id': 6, 'VCOUNT': 0, 'Vehicle_id': 18}

# %%
### Приведение координат к нужному формату для 5 запроса
for doc in db.sensors_data.find():
  db.sensors_data.update_one({'_id': {"$eq": doc['_id']}}, 
                             {"$set" : {"location": [ doc['Geolocation_coordinates_X'], doc['Geolocation_coordinates_Y']]}})

db.sensors_data.create_index([("location", GEOSPHERE)])
# Out:
# 'location_2dsphere'

# %%
for doc in db.sensors_data.find().limit(1):
  pprint(doc)
# Out:
# {'Data_accuracy': 1,
#  'Door_closing_time': '2020-05-25 08:00:12',
#  'Door_opening_time': '2020-05-25 08:00:00',
#  'Geolocation_coordinates_X': 55.820667,
#  'Geolocation_coordinates_Y': 37.663939,
#  'Passengers_came_in': 8,
#  'Passengers_got_off': 0,
#  'Public_vehicle_id': 1,
#  'Record_id': 1,
#  'Vehicle_id': 1,
#  '_id': ObjectId('61d0f9225a40174705e8cbdc'),
#  'location': [55.820667, 37.663939]}

# %%
# Проверка самописной функцией
def geo_dist(X_start,Y_start, X_end, Y_end):
  dist = 6371302 * 2 * math.asin(math.sqrt(math.pow(math.sin((X_start - abs(X_end)) * math.pi/180 / 2), 2) + 
                                           math.cos(X_start * math.pi/180) * 
                                           math.cos(abs(X_end) * math.pi/180) * 
                                           math.pow(math.sin((Y_start - Y_end) * math.pi/ 180/ 2), 2)))
  return dist


for stop in db.a_stop.find():
  counter = 0
  for sensor_note in db.sensors_data.find():
    
    if geo_dist(stop["Geolocation_coordinates_X"], stop['Geolocation_coordinates_Y'], sensor_note["Geolocation_coordinates_X"], sensor_note['Geolocation_coordinates_Y']) <= 5:
      counter += sensor_note['Passengers_came_in']

  print(stop['Stop_id'],'  =  ', counter)
# Out:
# 11   =   3267
# 12   =   3375
# 13   =   1625
# 14   =   1696
# 15   =   1574
# 16   =   1653
# 17   =   1643
# 18   =   1708
# 19   =   1614
# 20   =   1754
# 21   =   0
# 22   =   1753
# 23   =   1635
# 24   =   1608
# 25   =   1749
# 26   =   1656
# 27   =   1751
# 28   =   1647
# 29   =   1677

# %%
### Query 5
### Получить топ 5 остановок, где садится наибольшее количество людей.
### Для этого запроса понадобиться дополнительная встроенная функция geoNear() для расчета расстояния между двумя точками.
subresult = []
for doc in db.a_stop.find():
  cc = db.sensors_data.aggregate(
    [{"$geoNear":{"near": {"type": "Point", "coordinates": [doc['Geolocation_coordinates_X'], doc['Geolocation_coordinates_Y']]},
                  "distanceField": "dist",
                  "spherical": True,
                  "key": "location",
                  "maxDistance": 5
                }
      },
     {"$group": {"_id": None, "Passengers": {"$sum": "$Passengers_came_in"}}}
    ])
  for dd in cc:
    subresult.append({"Stop_id": doc['Stop_id'], "Name": doc['Name'], "Passengers": int(dd['Passengers'])})

j_s = json.dumps(subresult, ensure_ascii=False)
j_s = json.loads(j_s)

db.third_query_sub.insert_many(j_s)

result = db.third_query_sub.aggregate(
    [{"$project": {"_id": 0, "Name": 1, "Passengers": 1, "Stop_id": 1}},
     {"$sort": {"Passengers": DESCENDING}},
     {"$limit": 5}
    ]
)
for doc in result:
  pprint(doc)
# Out:
# {'Name': 'Улица Павла Корчагина, 5', 'Passengers': 3375, 'Stop_id': 12}
# {'Name': 'Улица Павла Корчагина', 'Passengers': 3267, 'Stop_id': 11}
# {'Name': 'Улица Павла Корчагина, 8 – Платформа Маленковская',
#  'Passengers': 1754,
#  'Stop_id': 20}
# {'Name': 'Улица Кибальчича', 'Passengers': 1753, 'Stop_id': 22}
# {'Name': 'Институт биологии и химии', 'Passengers': 1751, 'Stop_id': 27}

# %%
for i in db.third_query_sub.find({}):
  pprint(i)
# Out:
# {'Name': 'Улица Павла Корчагина',
#  'Passengers': 3267,
#  'Stop_id': 11,
#  '_id': ObjectId('61d0f9295a40174705e95688')}
# {'Name': 'Улица Павла Корчагина, 5',
#  'Passengers': 3375,
#  'Stop_id': 12,
#  '_id': ObjectId('61d0f9295a40174705e95689')}
# {'Name': '1-й Рижский переулок',
#  'Passengers': 1625,
#  'Stop_id': 13,
#  '_id': ObjectId('61d0f9295a40174705e9568a')}
# {'Name': 'Метро Алексеевская',
#  'Passengers': 1696,
#  'Stop_id': 14,
#  '_id': ObjectId('61d0f9295a40174705e9568b')}
# {'Name': 'Крестовский мост',
#  'Passengers': 1574,
#  'Stop_id': 15,
#  '_id': ObjectId('61d0f9295a40174705e9568c')}
# {'Name': 'Рижский вокзал',
#  'Passengers': 1653,
#  'Stop_id': 16,
#  '_id': ObjectId('61d0f9295a40174705e9568d')}
# {'Name': 'Графский переулок',
#  'Passengers': 1643,
#  'Stop_id': 17,
#  '_id': ObjectId('61d0f9295a40174705e9568e')}
# {'Name': 'Метро Алексеевская',
#  'Passengers': 1708,
#  'Stop_id': 18,
#  '_id': ObjectId('61d0f9295a40174705e9568f')}
# {'Name': '1-й Рижский переулок',
#  'Passengers': 1614,
#  'Stop_id': 19,
#  '_id': ObjectId('61d0f9295a40174705e95690')}
# {'Name': 'Улица Павла Корчагина, 8 – Платформа Маленковская',
#  'Passengers': 1754,
#  'Stop_id': 20,
#  '_id': ObjectId('61d0f9295a40174705e95691')}
# {'Name': 'Улица Павла Корчагина (нет посадки)',
#  'Passengers': 0,
#  'Stop_id': 21,
#  '_id': ObjectId('61d0f9295a40174705e95692')}
# {'Name': 'Улица Кибальчича',
#  'Passengers': 1753,
#  'Stop_id': 22,
#  '_id': ObjectId('61d0f9295a40174705e95693')}
# {'Name': 'Институт биологии и химии',
#  'Passengers': 1635,
#  'Stop_id': 23,
#  '_id': ObjectId('61d0f9295a40174705e95694')}
# {'Name': 'Метро ВДНХ',
#  'Passengers': 1608,
#  'Stop_id': 24,
#  '_id': ObjectId('61d0f9295a40174705e95695')}
# {'Name': 'Улица Космонавтов',
#  'Passengers': 1749,
#  'Stop_id': 25,
#  '_id': ObjectId('61d0f9295a40174705e95696')}
# {'Name': 'Ракетный бульвар',
#  'Passengers': 1656,
#  'Stop_id': 26,
#  '_id': ObjectId('61d0f9295a40174705e95697')}
# {'Name': 'Институт биологии и химии',
#  'Passengers': 1751,
#  'Stop_id': 27,
#  '_id': ObjectId('61d0f9295a40174705e95698')}
# {'Name': 'Улица Кибальчича',
#  'Passengers': 1647,
#  'Stop_id': 28,
#  '_id': ObjectId('61d0f9295a40174705e95699')}
# {'Name': 'Улица Павла Корчагина, 5',
#  'Passengers': 1677,
#  'Stop_id': 29,
#  '_id': ObjectId('61d0f9295a40174705e9569a')}
